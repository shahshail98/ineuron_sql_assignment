# %%
import mysql.connector as pycon
import numpy as np
import pandas as pd

# %%
dbcon=pycon.connect(user='root', password='ilovemymom@555', host='127.0.0.1', database='ineuron')

# %%
db1=pd.read_sql_query("""select * from Worker""",dbcon,parse_dates=True)
db1
# Out:
#     Wor_id First_name   Last_name  Salary           Join_date   Depart
# 0        1      Shail        Shah   25000 2016-09-26 02:02:45       DA
# 1        2    Shaheen       Hayat   30000 2017-09-20 22:00:55       DA
# 2        3       Amit      Thakur   90000 2015-04-14 12:03:30       BA
# 3        4      Srini  Masilamani  100000 2012-05-02 10:10:10       CA
# 4        5      Rakhi       Ghosh   22000 2018-10-15 09:02:45    Admin
# 5        6    Somrita        Jana   60000 2015-11-11 03:03:03       HR
# 6        7      Rehan     Kashyap   25000 2017-04-23 10:02:55  Account
# 7        9    Amitabh     Bacchan   30000 2017-04-23 10:02:55  Account
# 8       10        Anu   Sundriyal   50000 2013-08-22 03:03:45       HR
# 9       11     Shadab        alam   40000 2017-09-20 22:00:55       DA
# 10      12      Saroj       rajak  200000 2011-05-05 05:05:05      mgt
# 11      13     Rashmi      Kumari   30000 2014-02-02 13:13:13    Admin
# ...

# %%
db1=pd.read_sql_query("""select * from Worker order by salary desc""",dbcon,parse_dates=True)
db1
# Out:
#     Wor_id First_name   Last_name  Salary           Join_date   Depart
# 0       12      Saroj       rajak  200000 2011-05-05 05:05:05      mgt
# 1        4      Srini  Masilamani  100000 2012-05-02 10:10:10       CA
# 2        3       Amit      Thakur   90000 2015-04-14 12:03:30       BA
# 3        6    Somrita        Jana   60000 2015-11-11 03:03:03       HR
# 4       10        Anu   Sundriyal   50000 2013-08-22 03:03:45       HR
# 5       11     Shadab        alam   40000 2017-09-20 22:00:55       DA
# 6        2    Shaheen       Hayat   30000 2017-09-20 22:00:55       DA
# 7        9    Amitabh     Bacchan   30000 2017-04-23 10:02:55  Account
# 8       13     Rashmi      Kumari   30000 2014-02-02 13:13:13    Admin
# 9       14     Rashmi      Kumari   30000 2014-02-02 13:13:13    Admin
# 10      15     Rashmi      Kumari   30000 2014-02-02 13:13:13    Admin
# 11       1      Shail        Shah   25000 2016-09-26 02:02:45       DA
# ...

# %%
db2=pd.read_sql_query("""select max(salary) from Worker where salary not in(select max(salary) from worker)""",dbcon,parse_dates=True)
db2
# Out:
#    max(salary)
# 0       100000

# %%
db2=pd.read_sql_query("""select * from worker order by salary desc limit 4,1""",dbcon,parse_dates=True)
db2
# Out:
#    Wor_id First_name  Last_name  Salary           Join_date Depart
# 0      10        Anu  Sundriyal   50000 2013-08-22 03:03:45     HR
